# %% [markdown]
# # DuckDuckGo Image Scraper
#
# duckduckgo.com
#
# This was originally an image scraper notebook for creating deep learning datasets.
#
# It has since been turned into an installable library and is much easier to use as you can simply drop a few lines of code into your own notebook as you're experimenting.
#
# Docs are at [joedockrill.github.io/jmd_imagescraper/](https://joedockrill.github.io/jmd_imagescraper/)

# %% [markdown]
# ## Install

# %%
# !pip install -q jmd_imagescraper

# %% [markdown]
# ## Download images

# %%
from pathlib import Path
root = Path().cwd()/"images"
from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *
#liste=['SMART FORFOUR ', 'SMART FORTWO ', 'SSANGYONG KORANDO ', 'SSANGYONG REXTON ', 'SSANGYONG RODIUS ', 'SUBARU BRZ ', 'SUBARU FORESTER ', 'SUBARU WRX ', 'SUBARU SUBARU XV ', 'SUZUKI CELERIO ', 'SUZUKI JIMNY ', 'SUZUKI SWIFT ', 'SUZUKI SWIFT SPORT ', 'SUZUKI SX4', 'SUZUKI VITARA ', 'TESLA MODEL S ', 'TOYOTA AURIS ', 'TOYOTA AVENSIS ', 'TOYOTA AYGO ', 'TOYOTA 86', 'TOYOTA IQ ', 'TOYOTA LAND CRUISER 150', 'TOYOTA LAND CRUISER ', 'TOYOTA PRIUS ', 'TOYOTA PRIUS PLUS ', 'TOYOTA RAV4', 'TOYOTA VERSO ', 'TOYOTA VERSO S ', 'TOYOTA YARIS ', 'TOYOTA YARIS HYBRID ', 'VOLKSWAGEN CC ', 'VOLKSWAGEN BEETLE ', 'VOLKSWAGEN CRAFTER ', 'VOLKSWAGEN EOS ', 'VOLKSWAGEN GOLF ', 'VOLKSWAGEN GOLF SPORTSVAN ', 'VOLKSWAGEN JETTA ', 'VOLKSWAGEN PASSAT ', 'VOLKSWAGEN PHAETON ', 'VOLKSWAGEN POLO ', 'VOLKSWAGEN SCIROCCO ', 'VOLKSWAGEN SHARAN ', 'VOLKSWAGEN TIGUAN ', 'VOLKSWAGEN TOUAREG ', 'VOLKSWAGEN TOURAN ', 'VOLKSWAGEN UP! ', 'VOLVO S60', 'VOLVO S80', 'VOLVO V40', 'VOLVO V40 CROSS COUNTRY', 'VOLVO V60', 'VOLVO V60 HYBRID', 'VOLVO V70', 'VOLVO XC60', 'VOLVO XC70', 'VOLVO XC90']

#for i in range(len(liste)):
  #dossier=liste[i]
  #search=liste[i]
  #duckduckgo_search(root,dossier,search, max_results=3)

dossier="Normal"
search="regular cars"
duckduckgo_search(root,dossier,search, max_results=100)
# Out:
# Duckduckgo search: regular cars
# Downloading results into /content/images/Normal
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:11<00:00 Images downloaded]
#     </div>
# [PosixPath('/content/images/Normal/001_be0fd189.jpg'),
#  PosixPath('/content/images/Normal/002_b11db6d4.jpg'),
#  PosixPath('/content/images/Normal/003_4b37b24c.jpg'),
#  PosixPath('/content/images/Normal/004_e4bbeab2.jpg'),
#  PosixPath('/content/images/Normal/005_19b7b9e3.jpg'),
#  PosixPath('/content/images/Normal/006_6fc8d04b.jpg'),
#  PosixPath('/content/images/Normal/007_f6041eb5.jpg'),
#  PosixPath('/content/images/Normal/008_036cda7f.jpg'),
#  PosixPath('/content/images/Normal/009_8654a27f.jpg'),
#  PosixPath('/content/images/Normal/010_fdcbd6b3.jpg'),
#  PosixPath('/content/images/Normal/011_7bcae165.jpg'),
#  PosixPath('/content/images/Normal/012_4283f4b2.jpg'),
#  PosixPath('/content/images/Normal/013_1a7d657a.jpg'),
#  PosixPath('/content/images/Normal/014_587d3d54.jpg'),
#  PosixPath('/content/images/Normal/015_80927199.jpg'),
#  PosixPath('/content/images/Normal/016_b44fdecd.jpg'),
#  PosixPath('/content/images/Normal/017_e7b4bb07.jpg'),
#  PosixPath('/content/images/Normal/018_77166884.jpg'),
#  PosixPath('/content/images/Normal/019_58db9636.jpg'),
#  PosixPath('/content/images/Normal/020_95882212.jpg'),
#  PosixPath('/content/images/Normal/021_79e5e467.jpg'),
#  PosixPath('/content/images/Normal/022_a5a95d69.jpg'),
#  PosixPath('/content/images/Normal/023_34b35be6.jpg'),
#  PosixPath('/content/images/Normal/024_a2007a19.jpg'),
#  PosixPath('/content/images/Normal/025_4de83a59.jpg'),
#  PosixPath('/content/images/Normal/026_a2f54daf.jpg'),
#  PosixPath('/content/images/Normal/027_ec5edeea.jpg'),
#  PosixPath('/content/images/Normal/028_18be42fa.jpg'),
#  PosixPath('/content/images/Normal/029_3df67f76.jpg'),
#  PosixPath('/content/images/Normal/030_3cc9378a.jpg'),
#  PosixPath('/content/images/Normal/031_5f52f68b.jpg'),
#  PosixPath('/content/images/Normal/032_d71c3d16.jpg'),
#  PosixPath('/content/images/Normal/033_3caac4af.jpg'),
#  PosixPath('/content/images/Normal/034_f3743102.jpg'),
#  PosixPath('/content/images/Normal/035_b7c1fb28.jpg'),
#  PosixPath('/content/images/Normal/036_5461c02f.jpg'),
#  PosixPath('/content/images/Normal/037_72f976de.jpg'),
#  PosixPath('/content/images/Normal/038_4495f2d7.jpg'),
#  PosixPath('/content/images/Normal/039_5f83d4bb.jpg'),
#  PosixPath('/content/images/Normal/040_442f20db.jpg'),
#  PosixPath('/content/images/Normal/041_b54621e9.jpg'),
#  PosixPath('/content/images/Normal/042_7d13b09f.jpg'),
#  PosixPath('/content/images/Normal/043_3770b4f9.jpg'),
#  PosixPath('/content/images/Normal/044_287632ad.jpg'),
#  PosixPath('/content/images/Normal/045_cd653479.jpg'),
#  PosixPath('/content/images/Normal/046_f309b8af.jpg'),
#  PosixPath('/content/images/Normal/047_9e091b7c.jpg'),
#  PosixPath('/content/images/Normal/048_6c42eba8.jpg'),
#  PosixPath('/content/images/Normal/049_69d601c0.jpg'),
#  PosixPath('/content/images/Normal/050_fe718fd1.jpg'),
#  PosixPath('/content/images/Normal/051_b5d6fe1c.jpg'),
#  PosixPath('/content/images/Normal/052_7a7bbcfc.jpg'),
#  PosixPath('/content/images/Normal/053_1d96e1ff.jpg'),
#  PosixPath('/content/images/Normal/054_e0201c7c.jpg'),
#  PosixPath('/content/images/Normal/055_f3f6aad0.jpg'),
#  PosixPath('/content/images/Normal/056_4f10131d.jpg'),
#  PosixPath('/content/images/Normal/057_3cfd3653.jpg'),
#  PosixPath('/content/images/Normal/058_70d1454f.jpg'),
#  PosixPath('/content/images/Normal/059_77188f11.jpg'),
#  PosixPath('/content/images/Normal/060_1b04016d.jpg'),
#  PosixPath('/content/images/Normal/061_5af5a1ce.jpg'),
#  PosixPath('/content/images/Normal/062_1817671f.jpg'),
#  PosixPath('/content/images/Normal/063_c0de774b.jpg'),
#  PosixPath('/content/images/Normal/064_5c5c7c78.jpg'),
#  PosixPath('/content/images/Normal/065_035e350c.jpg'),
#  PosixPath('/content/images/Normal/066_1448ec2e.jpg'),
#  PosixPath('/content/images/Normal/067_b37689f7.jpg'),
#  PosixPath('/content/images/Normal/068_5de0b05a.jpg'),
#  PosixPath('/content/images/Normal/069_24fbb91e.jpg'),
#  PosixPath('/content/images/Normal/070_6ffa1408.jpg'),
#  PosixPath('/content/images/Normal/071_58cae554.jpg'),
#  PosixPath('/content/images/Normal/072_43b8c3b1.jpg'),
#  PosixPath('/content/images/Normal/073_9f1af271.jpg'),
#  PosixPath('/content/images/Normal/074_76f5b879.jpg'),
#  PosixPath('/content/images/Normal/075_5c907573.jpg'),
#  PosixPath('/content/images/Normal/076_a90c2829.jpg'),
#  PosixPath('/content/images/Normal/077_23f60e1b.jpg'),
#  PosixPath('/content/images/Normal/078_d4600b6b.jpg'),
#  PosixPath('/content/images/Normal/079_fd43f8ec.jpg'),
#  PosixPath('/content/images/Normal/080_f6309ce1.jpg'),
#  PosixPath('/content/images/Normal/081_1189a9cc.jpg'),
#  PosixPath('/content/images/Normal/082_99f265ab.jpg'),
#  PosixPath('/content/images/Normal/083_37546e89.jpg'),
#  PosixPath('/content/images/Normal/084_753503f9.jpg'),
#  PosixPath('/content/images/Normal/085_889da05c.jpg'),
#  PosixPath('/content/images/Normal/086_b4440fe8.jpg'),
#  PosixPath('/content/images/Normal/087_765ed678.jpg'),
#  PosixPath('/content/images/Normal/088_21ebe5fe.jpg'),
#  PosixPath('/content/images/Normal/089_3a9f9aa1.jpg'),
#  PosixPath('/content/images/Normal/090_392f699a.jpg'),
#  PosixPath('/content/images/Normal/091_63285adc.jpg'),
#  PosixPath('/content/images/Normal/092_d971b04e.jpg'),
#  PosixPath('/content/images/Normal/093_38a1f70b.jpg'),
#  PosixPath('/content/images/Normal/094_184c4b8d.jpg'),
#  PosixPath('/content/images/Normal/095_1d42194c.jpg'),
#  PosixPath('/content/images/Normal/096_4baddfe0.jpg'),
#  PosixPath('/content/images/Normal/097_f3172104.jpg'),
#  PosixPath('/content/images/Normal/098_3a319fc5.jpg'),
#  PosixPath('/content/images/Normal/099_85da98d5.jpg'),
#  PosixPath('/content/images/Normal/100_6f993669.jpg')]

# %% [markdown]
# ## Deleting all images

# %%
rmtree(root)

# %% [markdown]
# ## Displaying the image cleaner
#
# Use this to get rid of unsuitable images without leaving your notebook

# %%
from jmd_imagescraper.imagecleaner import *

display_image_cleaner(root)
# Out:
# HBox(children=(Button(description='|<<', layout=Layout(width='60px'), style=ButtonStyle()), Button(description…
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive
